# %%
# This file plays the mpc motion only in viz
# %load_ext autoreload
# %autoreload 2

import time
import numpy as np
import pinocchio as pin
from matplotlib import pyplot as plt

from robot_properties_solo.config import Solo12Config

from py_biconvex_mpc.bullet_utils.solo_mpc_env import Solo12Env

from abstract_acyclic_gen import SoloAcyclicGen
# from plan_cartwheel import plan
# Out:
# pybullet build time: Jul  2 2021 21:43:18

# %%
robot = Solo12Config.buildRobotWrapper()
rmodel = robot.model
rdata = robot.data

viz = pin.visualize.MeshcatVisualizer(robot.model, robot.collision_model, robot.visual_model)
viz.initViewer(open=False)
viz.loadViewerModel()

pin_robot = Solo12Config.buildRobotWrapper()
pin_robot = Solo12Config.buildRobotWrapper()
urdf = Solo12Config.urdf_path


q0 = np.array(Solo12Config.initial_configuration)
v0 = pin.utils.zero(pin_robot.model.nv)
x0 = np.concatenate([q0, pin.utils.zero(pin_robot.model.nv)])
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7001/static/

# %%
viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7001/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %%
from plan_hifive import plan

sim_t = 0.0
sim_dt = .001
index = 0
pln_ctr = 0
plan_freq = 0.2 # sec
update_time = 0.0 # sec (time of lag)
lag = int(update_time/sim_dt)

mg = SoloAcyclicGen(pin_robot, urdf, plan_freq)
mg.update_motion_params(plan, sim_t)

q = q0
v = v0

for o in range(5):
    contact_configuration = np.array([1,1,1,1])
    xs, us, f = mg.optimize(q, v, sim_t)
    xs = xs[lag:]
    us = us[lag:]
    f = f[lag:]

    time.sleep(0.001)
    for ind in range(int(plan_freq/sim_dt)):
        viz.display(xs[ind][:robot.model.nq])

    q = xs[int(plan_freq/sim_dt)-1][0:pin_robot.model.nq]
    v = xs[int(plan_freq/sim_dt)-1][pin_robot.model.nq:]

    sim_t += plan_freq
# Out:
# Initialized Kino-Dyn planner
# Maximum iterations reached
# Final norm: 0.00208319
# Cost Time : 0.0014176368713378906
# Solve Time :  0.037088871002197266
#  ==================================
# Maximum iterations reached
# Cost Time : 0.0008788108825683594
# Solve Time :  0.03238344192504883
#  ==================================
# Final norm: 0.00209405
# Maximum iterations reached
# Final norm: 0.00264541
# Cost Time : 0.0008709430694580078
# Solve Time :  0.03167867660522461
#  ==================================
# Maximum iterations reached
# Final norm: 0.00101619
# Cost Time : 0.0013725757598876953
# Solve Time :  0.03029799461364746
#  ==================================
# Maximum iterations reached
# Cost Time : 0.0008265972137451172
# Solve Time :  0.016243457794189453
#  ==================================
# Final norm: 0.00071865
# Maximum iterations reached
# Final norm: 0.000924132
# Cost Time : 0.0008320808410644531
# Solve Time :  0.019629478454589844
#  ==================================
# Maximum iterations reached
# Cost Time : 0.00081634521484375
# Solve Time :  Final norm: 0.000550081
# 0.015554428100585938
#  ==================================
# Maximum iterations reached
# Cost Time : 0.001092672348022461
# Solve Time :  Final norm: 0.000899062
# 0.013385772705078125
#  ==================================
# Maximum iterations reached
# Cost Time : 0.0013484954833984375
# Solve Time :  0.013751029968261719
#  ==================================
# Final norm: 0.000676984
# Maximum iterations reached
# Cost Time : 0.0011162757873535156
# Final norm: 0.00098067
# Solve Time :  0.012183904647827148
#  ==================================

# %%
mg.plot()
