# %%
# This file plays the mpc motion only in viz
# %load_ext autoreload
# %autoreload 2

import time
import numpy as np
import pinocchio as pin
import crocoddyl
from matplotlib import pyplot as plt

from py_biconvex_mpc.motion_planner.cpp_biconvex import BiConvexMP
from inverse_kinematics_cpp import InverseKinematics
from py_biconvex_mpc.ik_utils.gait_generator import GaitGenerator
from robot_properties_solo.config import Solo12Config

import raisimpy as raisim
import subprocess
from py_biconvex_mpc.bullet_utils.solo_mpc_env import Solo12Env

from mpc_cartwheel import generate_plan
# Out:
# solo import
# pybullet build time: Jul  2 2021 21:43:18

# %%
robot = Solo12Config.buildRobotWrapper()
rmodel = robot.model
rdata = robot.data

viz = pin.visualize.MeshcatVisualizer(robot.model, robot.collision_model, robot.visual_model)
viz.initViewer(open=False)
viz.loadViewerModel()

pin_robot = Solo12Config.buildRobotWrapper()
pin_robot = Solo12Config.buildRobotWrapper()
urdf = Solo12Config.urdf_path


q0 = np.array(Solo12Config.initial_configuration)
v0 = pin.utils.zero(pin_robot.model.nv)
x0 = np.concatenate([q0, pin.utils.zero(pin_robot.model.nv)])
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7001/static/

# %%
viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7001/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %%
sim_t = 0.0
sim_dt = .001
index = 0
pln_ctr = 0
plan_freq = 0.05 #0.05 # sec
update_time = 0.0 # sec (time of lag)
lag = int(update_time/sim_dt)

q = q0
v = v0

for o in range(2):
    contact_configuration = np.array([1,1,1,1])
    xs, us, f = generate_plan(q, v, sim_t)
    xs = xs[lag:]
    us = us[lag:]
    f = f[lag:]

    time.sleep(0.001)
    for ind in range(int(plan_freq/sim_dt)):
        viz.display(xs[ind][:robot.model.nq])
    
    q = xs[int(plan_freq/sim_dt)-1][0:pin_robot.model.nq]
    v = xs[int(plan_freq/sim_dt)-1][pin_robot.model.nq:]

    sim_t += plan_freq
# Out:
# [0.2        0.00038689 0.22596527 0.         0.         0.
#  0.         0.         0.        ]
# breaking outer loop due to norm ...
# Maximum iterations reached
# Final norm: 0.000999675
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelControl: Use ResidualModelControl with CostModelResidual
# [ 6.15474039e-01  1.73516062e-04  2.28683596e-01  8.53931723e-01
#   1.28490230e-04 -4.31168117e-02  2.38099419e-04  4.60143764e-02
#   3.31631866e-04]
# breaking outer loop due to norm ...
# Maximum iterations reached
# Final norm: 0.00099127
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCoMPosition: Use ResidualModelCoMPosition with CostModelResidual
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelCentroidalMomentum: Use ResidualModelCentroidalMomentum with CostModelResidual class
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelState: Use ResidualModelState with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated: Do not use FrameTranslation.
# Deprecated: Do not use FrameTranslation.
# Deprecated CostModelFrameTranslation: Use ResidualModelFrameTranslation with CostModelResidual
# Deprecated CostModelControl: Use ResidualModelControl with CostModelResidual
