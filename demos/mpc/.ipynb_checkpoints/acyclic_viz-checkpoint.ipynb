# %%
# This file plays the mpc motion only in viz
# %load_ext autoreload
# %autoreload 2

import time
import numpy as np
import pinocchio as pin
from matplotlib import pyplot as plt

from robot_properties_solo.config import Solo12Config
from abstract_acyclic_gen import SoloAcyclicGen
# from plan_cartwheel import plan

# %%
robot = Solo12Config.buildRobotWrapper()
rmodel = robot.model
rdata = robot.data

viz = pin.visualize.MeshcatVisualizer(robot.model, robot.collision_model, robot.visual_model)
viz.initViewer(open=False)
viz.loadViewerModel()

pin_robot = Solo12Config.buildRobotWrapper()
pin_robot = Solo12Config.buildRobotWrapper()
urdf = Solo12Config.urdf_path


q0 = np.array(Solo12Config.initial_configuration)
v0 = pin.utils.zero(pin_robot.model.nv)
x0 = np.concatenate([q0, pin.utils.zero(pin_robot.model.nv)])
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %%
viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7000/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %%
from motions.plan_jump import plan

sim_t = 0.0
sim_dt = .001
index = 0
pln_ctr = 0
plan_freq = 0.8 # sec
update_time = 0.0 # sec (time of lag)
lag = int(update_time/sim_dt)

mg = SoloAcyclicGen(pin_robot, urdf, plan_freq)
mg.update_motion_params(plan, sim_t)

q = q0
v = v0

for o in range(1):
    contact_configuration = np.array([1,1,1,1])
    xs, us, f = mg.optimize(q, v, sim_t)
    xs = xs[lag:]
    us = us[lag:]
    f = f[lag:]

    time.sleep(0.001)
    for ind in range(int(plan_freq/sim_dt)):
        viz.display(xs[ind][:robot.model.nq])

    q = xs[int(plan_freq/sim_dt)-1][0:pin_robot.model.nq]
    v = xs[int(plan_freq/sim_dt)-1][pin_robot.model.nq:]

    sim_t += plan_freq
# Out:
# Initialized Kino-Dyn planner
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27078/3244096957.py in <module>
#      17 for o in range(1):
#      18     contact_configuration = np.array([1,1,1,1])
# ---> 19     xs, us, f = mg.optimize(q, v, sim_t)
#      20     xs = xs[lag:]
#      21     us = us[lag:]
#
# ~/devel/workspace/biconvex_mpc/demos/mpc/abstract_acyclic_gen.py in optimize(self, q, v, t, X_wm, F_wm, P_wm)
#     298         self.create_contact_plan(q, v, t)
#     299         #Creates costs for IK and Dynamics
# --> 300         self.create_costs(q, v, t)
#     301
#     302         t2 = time.time()
#
# ~/devel/workspace/biconvex_mpc/demos/mpc/abstract_acyclic_gen.py in create_costs(self, q, v, t, make_cyclic)
#     161                 for k in range(len(self.params.bounds)):
#     162                     if ft >= self.params.bounds[k][-2] and ft < self.params.bounds[k][-1]:
# --> 163                         self.bounds[i] = self.params.bounds[k][0:6]
#     164                         break
#     165             else:
#
# ValueError: could not broadcast input array from shape (5,) into shape (6,)

# %%
mg.plot(q, v, plot_force=False)
